# %% [markdown]
# # Python type casting

# %%
# all other datatypes to int & float is possible { (int(complex)=x , int(string)=X, float(complex)=x, float(string)=x }
# all other datatype to bool is possible and there is no issue.{ Non- zero argument = true| zero argument= False }
# all other datatypes to complex is possible. { complex(10,20,30)= X, complex() takes at most 2 arguments (3 given), complex('10','20')- 2 strings declared throws error}
# all other datatype to string is possible. {str(2,3)=X , str() argument 'encoding' must be str, not int}

# %% [markdown]
# - car()   -- car function without argument
#
# - asian_cars('tata', 'to') -- car function with 2 argument | type of arguemnt string
#
# - german_cars('audi', 'bmw', 'fereri', 'vw') -- germ car with 4 argument
#
# - today in this code i define 3 function function ens with ():

# %%
int(2.5)
# Out:
# 2

# %%
int(2+5j) 
# type casting not possible from complex to int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 int(2+5j) # type casting not possible
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten') #gives error as its not possible 
# type casting not possible from string to int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 int('ten') #gives error as its not possible
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int(True)
# Out:
# 1

# %%
float(True)
# Out:
# 1.0

# %%
float(2+7j)
# type casting not possible from complex to float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 float(2+7j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('twenty')
# type casting not possible from string to float
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 float('twenty')
#
# ValueError: could not convert string to float: 'twenty'

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2+5j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool( )
# Out:
# False

# %%
val1=[20,30,40,50]
val1
#python construtor (___init___) gives the size to the array in the backend
# Out:
# [20, 30, 40, 50]

# %%
import sys
sys.getsizeof(val1)
# Out:
# 88

# %%
complex(10)
# int to complex
# Out:
# (10+0j)

# %%
complex(10,20) 
# 1st part considered as real and 2nd part is imaginary part 
# int to complex
# Out:
# (10+20j)

# %%
complex(10,20,30)
# The above fucntion gives type error as complex has only 2 parts
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 complex(10,20,30)
#       2 # The above fucntion gives type error as complex has only 2 parts
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# float to complex
# Out:
# (2.3+0j)

# %%
complex(2.3,4.5)
# Out:
# (2.3+4.5j)

# %%
complex(23,4.5)
# Out:
# (23+4.5j)

# %%
complex(0,5)
# Out:
# 5j

# %%
complex(True)
# bool to complex
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True, False)
# Out:
# (1+0j)

# %%
bool(2+9j)
# Out:
# True

# %%
complex('10')
# string to complex
# Out:
# (10+0j)

# %%
complex('10','20')
# complex() can't take second arg if first is a string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10,'20')
# while casting from string to complex there is only one string allowed and not more than one. If we pass more than one it gives type error.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 complex(10,'20')
#
# TypeError: complex() second arg can't be a string

# %%
str(100)
# int to string
# Out:
# '100'

# %%
str(2.3)
# float to string
# Out:
# '2.3'

# %%
str(2+7j)
# complex to string
# Out:
# '(2+7j)'

# %%
str(True)
# bool to string
# Out:
# 'True'

# %%
str(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 str(2,3)
#
# TypeError: str() argument 'encoding' must be str, not int

# %%
str('Text')
# Out:
# 'Text'

# %% [markdown]
# # Python Operator

# %% [markdown]
# ### Arithmetic operators

# %%
x1,y1= 20,10
x1+y1
#operator= operand
# operator overloading: part of polymorphism: oops
# Out:
# 30

# %%
x1-y1
# Out:
# 10

# %%
x1*y1
# Out:
# 200

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
2*3
# Out:
# 6

# %%
2**3 # referes to 2 power 3 or 2 cube
# Out:
# 8

# %% [markdown]
# ## Assigment operator

# %%
x=2
x
# Out:
# 2

# %%
x=x+2
x
# Out:
# 4

# %%
x+=2
x
# Out:
# 6

# %%
x-=2
x
# Out:
# 4

# %%
x*=2
x
# Out:
# 8

# %%
x*=2
x
# Out:
# 16

# %%
x**=2
x
# Out:
# 256

# %% [markdown]
# ## unary operator

# %% [markdown]
# #### unary means 1|| Binary means 2
# #### Here we are applying unary minus(-) operator on the operand n, the value on m becomes -7 which indicates it as a negative value.

# %%
n=7
n
# Out:
# 7

# %%
m=-n
m
# Out:
# -7

# %% [markdown]
# ### Relational Operator

# %%
a=5
b=6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
print(a)
print(b)
# Out:
# 5
# 6

# %% [markdown]
# ## Logical operators

# %%
a=5
b=4

# %%
a<8 and b<5
# and Table
#  00 0
#  01 0
#  10 0
#  11 1
# Out:
# True

# %%
a<8 and b>5
# Out:
# False

# %%
a<8 or b<5

# or Table
#  00 0
#  01 1
#  10 1
#  11 1
# Out:
# True

# %%
a>8 and b>5
# Out:
# False

# %%
a<8 and b>5
# Out:
# False
