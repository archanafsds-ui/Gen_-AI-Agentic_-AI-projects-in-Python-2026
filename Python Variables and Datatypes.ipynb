# %% [markdown]
# # **Python Datatype/Variables**

# %% [markdown]
# # Variable declared as (variable = object = identifier)
#
# - variable(object) = value (datatypes)

# %%
i=5
i
# Out:
# 5

# %%
it = 20
IT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 it = 20
# ----> 2 IT
#
# NameError: name 'IT' is not defined

# %% [markdown]
# ![Variable](C:\Users\siddharth\Pictures\Screenshots)

# %%
nit@ = 8 
nit@
# Out:
#   Cell In[6], line 1
#     nit@ = 8
#          ^
# SyntaxError: invalid syntax

# %%
nit_ = 32
nit_
# Out:
# 32

# %%
1030 = nit
# Out:
#   Cell In[9], line 1
#     1030 = nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1nit = 10 
1nit
# Out:
#   Cell In[11], line 1
#     1nit = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1 = 10
nit1
# Out:
# 10

# %%
_nit = 5
_nit
# Out:
# 5

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
for=45
for
#keywords cannot be used as variable. It throws error.
# Out:
#   Cell In[26], line 1
#     for=45
#        ^
# SyntaxError: invalid syntax

# %%
For=45
For

# %% [markdown]
# #  Python Datatype

# %%
i=5
i
# Out:
# 5

# %%
type(i)
#type() give the datatype of the object/value
# Out:
# int

# %%
id(i)
# id () function is used to get the location of memory
# Out:
# 140711070835752

# %%
f = 110.45
f
# Out:
# 110.45

# %%
type(f)
# Out:
# float

# %%
f=110.45

# %%
type(f)
# Out:
# float

# %%
gold_price=14800.78
gold_price
# Out:
# 14800.78

# %%
type(gold_price)
# Out:
# float

# %%
10+5
100-5
10*5
#only the last code will be executed among all the above 
# if you want to multiple output then use the print() function
#argument==paramater
# Out:
# 50

# %%
print(10+5)
print(10-5)
print(10*5)
# The above one will print all lines individually
# Out:
# 15
# 5
# 50

# %%
f1 = 2.4e1
f1
# 2.4* 10(e1) gives result in float format. e2=100
# Out:
# 24.0

# %%
type(f1)
# Out:
# float

# %%
f2 = 3.5e3 
f2
#e3 refers to 1000
# Out:
# 3500.0

# %%
F1=2.4e1
F2=3.5e3
#float we will allow only e letter(exponential representation)

# %% [markdown]
# # Boolean value

# %%
True
#true is treated as logic 1
# Out:
# True

# %%
False
#true is treated as logic 0
# Out:
# False

# %%
True+True
# Out:
# 2

# %%
True + False - False
# Out:
# 1

# %%
False+False
# Out:
# 0

# %%
True*True
# Out:
# 1

# %%
False/True
#float division
# Out:
# 0.0

# %%
False//True
#int division
# Out:
# 0

# %%
True/False
#gives infinity. Hence, will give runtime error
#to fix this type of error we introduce exceptional handling
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 True/False
#       2 #gives infinity. Hence, will give runtime error
#       3 #to fix this type of error we introduce exceptional handling
#
# ZeroDivisionError: division by zero

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # Complex

# %%
C=10+20j
#10= real, 20=imaginary, j=square root of -1

# %%
type(C)
# Out:
# complex

# %%
C.imag
#c.tab ...select imag to get the imaginary part of the C function.
# Out:
# 20.0

# %%
C.real
#c.tab ...select real to get the imaginary part of the C function.
# Out:
# 10.0

# %%
f1=5.6
F2=1000

# %%
c=f1+F2
print(c)
# Out:
# 1005.6

# %%
f3=3.5e3

# %%
f3
# Out:
# 3500.0

# %%
F1=2.4e1

# %%
F1
# Out:
# 24.0

# %%
b=True
b1=False 
c=b+b1
c
# Out:
# 1

# %%
type(c)
# Out:
# int

# %%
c=1+2j
c1=3+4j
d=c+c1
d
# Out:
# (4+6j)

# %% [markdown]
# # String

# %%
#String functions encoded in '', " ", '''  '''  quotes (sngle, double, triple quotes only)

# %%
'Welcome to world and request everyone to maintain calm and peace'
# Out:
# 'Welcome to world and request everyone to maintain calm and peace'

# %%
"Welcome to world
and request everyone to 
maintain calm and peace"
# Out:
#   Cell In[11], line 1
#     "Welcome to world
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''Welcome to world and 
request everyone to maintain 
calm and peace''' 
#single and double quotes used to have single line comment while 3 quotes used to have multiline comment 
#python indexing begins with 0 (divided into 2 parts )
#forward indexing ---->>>>>>>> always start from (left - right) count from 0 
#backward indexing  <<<<<<<------ always starts from (right-left) count away from -1
# Out:
# 'Welcome to world and \nrequest everyone to maintain \ncalm and peace'

# %%
s='Python'
s1='Welcome to gen AI agentic AI'
s+" "+s1
# Out:
# 'Python Welcome to gen AI agentic AI'

# %%
s1[3]
# Out:
# 'c'

# %%
s1[5]
# Out:
# 'm'

# %%
s1[30]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 s1[30]
#
# IndexError: string index out of range

# %%
s1[-3]
# Out:
# ' '

# %%
s1[-5]
# Out:
# 'i'

# %%
len(s1)
# Out:
# 28

# %%
len(s)
# Out:
# 6

# %%
#string indexing : to find the position if a letter 
#string slicing is to extract array of a string

# %%
s1[:]
# Out:
# 'Welcome to gen AI agentic AI'

# %%
s1[1:4] #forwards slicing
# Out:
# 'elc'

# %%
s1[1:10]
# Out:
# 'elcome to'

# %%
#[:]  -prints all strings 
#[3:] left index satrtign from 3 till end of string 
#[:6] from start index to n-1(5th index)
#[2:9] print values from 2 index to n-1(8) index
#[2:9:9:2] from 2nd index to 8 index but need to step by 2

# %%
s2='nareshtechnology'
s2
# Out:
# 'nareshtechnology'

# %%
s2[:]
# Out:
# 'nareshtechnology'

# %%
len(s2)
# Out:
# 16

# %%
s2[3:]
# Out:
# 'eshtechnology'

# %%
s2[:6]
# Out:
# 'naresh'

# %%
s3='welcometeam'
s3
# Out:
# 'welcometeam'

# %%
s3[1:8:3]
# Out:
# 'eot'

# %%
s3[::-1] # reverse string skipping no letter
# Out:
# 'maetemoclew'

# %%
s3[::2] #all string with step up 2 means select alternative  or skip 1 and fetch next
# Out:
# 'wloeem'

# %%
s3[::-2] #write from reverse order with step up 2
# Out:
# 'meeolw'
