# %% [markdown]
# # List Data structure

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1=[10,2.3,1+2j, True, 'more',[1,2,3]]
l1
# Out:
# [10, 2.3, (1+2j), True, 'more', [1, 2, 3]]

# %%
len(l1)
# Out:
# 6

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), True, 'more', [1, 2, 3]]

# %%
print(id(l))
print(id(l1))
# Out:
# 1568942916736
# 1568942711936

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l2=l.copy()
l2
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(id(l))
print(id(l1)) 
print(id(l2))
# Out:
# 1568942916736
# 1568942711936
# 1568942948864

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
len(l2)
# Out:
# 6

# %%
l2.clear()
l2
# Out:
# []

# %%
len(l2)
# Out:
# 0

# %%
l2
# Out:
# []

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l.count(20)
#counts the coccurance of the object
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l.count(100)
# Out:
# 0

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), True, 'more', [1, 2, 3]]

# %%
a = [1,2,3]
b = [4,5,6]
a.extend(b)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l2 = []
l2
# Out:
# []

# %%
l2.extend(l)
l2
# Out:
# [10, 20, 30, 40, 50, 10, 10, 20, 30, 40, 50, 10]

# %%
l2.extend(l1)
l2
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  10,
#  2.3,
#  (1+2j),
#  True,
#  'more',
#  [1, 2, 3]]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), True, 'more', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10, 10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), True, 'more', [1, 2, 3]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l[0] 
# check the item in 0 position of l list
# Out:
# 10

# %%
l[0] = 100

# %%
job = [5000]
job
# Out:
# [5000]

# %%
job[0]
# Out:
# 5000

# %%
job[0] = 10000

# %%
job
# Out:
# [10000]

# %%
l
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
l[-2] = 500
l
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l.index(100)
#Return first index of value.
# Out:
# 0

# %%
l2
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  10,
#  2.3,
#  (1+2j),
#  True,
#  'more',
#  [1, 2, 3]]

# %%
l2.index(10)
# Out:
# 0

# %%
l
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l.insert(2, 25)
l
# Out:
# [100, 20, 25, 30, 40, 500, 10]

# %%
l
# Out:
# [100, 20, 25, 30, 40, 500, 10]

# %%
l2
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  10,
#  2.3,
#  (1+2j),
#  True,
#  'more',
#  [1, 2, 3]]

# %%
l2.pop() 
#Remove and return item at index (default last).
# Out:
# [1, 2, 3]

# %%
l2.pop()
# Out:
# 'more'

# %%
l2.pop(-1)
# Out:
# (1+2j)

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10, 10, 20, 30, 40, 50, 10, 10, 2.3]

# %%
l2.pop(2)
# Out:
# 30

# %%
l2.remove(10)
# Remove first occurrence of value.

# %%
l2
# Out:
# [20, 50, 10, 20, 30, 50, 10, 10, 2.3]

# %%
l2
# Out:
# [10, 20, 50, 10, 10, 20, 30, 50, 10, 10, 2.3]

# %%
l2.pop(4)
# Out:
# 10

# %%
l2
# Out:
# [10, 20, 50, 10, 20, 30, 50, 10, 10, 2.3]

# %%
l
# Out:
# [100, 20, 25, 30, 40, 500, 10]

# %%
l.reverse()
l
# Out:
# [100, 20, 25, 30, 40, 500, 10]

# %%
l.sort() #ascending order 
l
# Out:
# [10, 20, 25, 30, 40, 100, 500]

# %%
l.sort(reverse=True)
l
# Out:
# [500, 100, 40, 30, 25, 20, 10]

# %%
l3 = [10,20,[2,3],3]
l3
# Out:
# [10, 20, [2, 3], 3]

# %%
l3[2]=[2] #replacing 2nd position with value lit 2
l3
# Out:
# [10, 20, [2], 3]

# %%
l
# Out:
# [500, 100, 40, 30, 25, 20, 10]

# %%
5000 in l
# Out:
# False

# %%
for i in l:
    print(i)
# Out:
# 500
# 100
# 40
# 30
# 25
# 20
# 10
