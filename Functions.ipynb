# %% [markdown]
# ## Funtions, Module, Package

# %%
x=sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x=sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
x=sqrt(25)
# as sqrt module is not defined we've to import the module
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import math
# ----> 2 x=sqrt(25)
#       3 # as sqrt module is not defined we've to import the module
#
# NameError: name 'sqrt' is not defined

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
x=round(math.sqrt(25))
x
# Out:
# 5

# %%
math.floor(3.8)
# Out:
# 3

# %%
math.ceil(3.8)
# Out:
# 4

# %%
math.pow(3,2)
# Out:
# 9.0

# %%
pow(3,2)
# Out:
# 9

# %%
math.pi
# Out:
# 3.141592653589793

# %%
pi=3.7
pi
#in python there is no constant. There are only variables
# Out:
# 3.7

# %%
help()
# left * indicates that code is executing. If needed any help with function type for the same in the help serch bar. to quit use "q"

# %%
m.sqrt(49)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 m.sqrt(49)
#
# NameError: name 'm' is not defined

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
import math as m

# %%
m.sqrt(49)
# Out:
# 7.0

# %%
from math import sqrt, pow
print(pow(2,3))
print(m.sqrt(10))
# Out:
# 8.0
# 3.1622776601683795

# %%
from math import *
#selecting all functions

# %%
from math import sqrt, pow, floor,ceil

# %% [markdown]
# ## input function()

# %%
input()
# Out:
#  hello
# 'hello'

# %%
input()
input()
# Out:
#  hira
#  mandi
# 'mandi'

# %%
x=input()
y=input()
z=x+y
print(z)
# input always takes string format
# Out:
#  3
#  2
# 32

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x=int(input())
y=int(input())
z=x+y
print(z)
# Out:
#  3
#  2
# 5

# %%
x=int(input('Enter 1st number'))
y=int(input('Enter 2nd number'))
z=print(x+y)
# Out:
# Enter 1st number 4
# Enter 2nd number 5
# 9

# %%
a=input('enter username')
b=input('enter Password')
c=print(a+b)
# Out:
# enter username archana
# enter Password more
# archanamore

# %%
st=input('enter a string')
print(st)
# Out:
# enter a string Testing
# Testing

# %%
st=input('enter a string')[0]
print(st)
# Out:
# enter a string Testing
# T

# %%
st=input('enter a string')[9:13]
print(st)
# Out:
# enter a string welcometonareshit
# nare
